% %%
%plot --format svg
% Out:
% [Errno 9] Bad file descriptor

% %% [markdown]
% ### Set up wavelet parameters

% %%
multi_globals
type, p, method, rho, N, M
% Out:
% [Errno 9] Bad file descriptor
% [Errno 9] Bad file descriptor

% %% [markdown]
% ### Load the data

% %%
[ax, aximp] = prepsig(5);
plot(aximp')

% %% [markdown]
% `multi_data_same` produces test data with the same impulse response for each channel. The simulated original signal is `testyori`.
%
% `ax` and `aximp` are the matrices containing the ANITA observations (in each row) and the impulse responses associated with the observations.

% %%
multi_data

% %%
size(ax)
% Out:
% ans =
%
%      15   1561

% %%
plot(aximp'); axis([1 1024])

% %%
plot(testyori)

% %%
plot( conv(testvec, K/10)(1:1024))

% %%
testvec_2
z = [testvec zeros(1, 512)];
plot(z); axis([1 1024])

% %%
multi_globals
type, p
% Out:
% [Errno 9] Bad file descriptor
% [Errno 9] Bad file descriptor

% %%
w = wtrans([testvec zeros(1, 512)], type, p);
% Out:
% [Errno 9] Bad file descriptor
% [Errno 9] Bad file descriptor

% %%
plotcoeffs(w, p)
% Out:
% [Errno 9] Bad file descriptor
% [Errno 9] Bad file descriptor

% %%
plot(z); axis([1 1024])
