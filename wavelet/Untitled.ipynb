% %%
multi_data_same

% %%
%plot -f svg -s1000,300

% %%
available_graphics_toolkits()
graphics_toolkit('fltk')
get(0, 'screenpixelsperinch')
% Out:
% ans =
% {
%   [1,1] = fltk
%   [1,2] = gnuplot
% }
% ans =  96.126

% %%
plot(wax'); xlim([0 1024])

% %%
plot(wax(3,:)); xlim([1 1024])

% %%
t = linspace(0,6*pi,100);
plot(sin(t))
grid on
hold on
plot(cos(t), 'r')

% %%
plot(1:5)

% %%
%plot -f svg -s1000,600

% %%
plotcoeffs(wax(3,:),3)

% %%
multi_globals

% %%
multi_demoe_onevsmore
% Out:
% par
% error: std: X must be a numeric vector or matrix
% error: called from
%     std at line 73 column 5
%     multi_fpar at line 4 column 10
%     multi_demoe_onevsmore at line 23 column 8

% %%
[alpha_par, ratio_par, sigl_par] = multi_getscOri_fpar(wax, aximp, testyori, type, p, noiseax);

% %%
alpha_par
% Out:
% alpha_par =
%
%    0.232197   0.021436   0.168389   0.292139   0.145186   0.116182

% %%
ww = multi_fpar(wax, aximp, testyori, noiseax, alpha_par );

% %%
%plot -f svg -s1000,300

% %%
plot(ww); xlim([1 1024])
